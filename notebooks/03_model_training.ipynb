# %%
# Cell 1. Import Libraries
import pickle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import (
    accuracy_score, classification_report,
    confusion_matrix, roc_auc_score, roc_curve
)

# %%
# Cell 2. Load the data we prepared in notebook 02
X_train = pickle.load(open("../models/X_train.pkl", "rb"))
X_test  = pickle.load(open("../models/X_test.pkl",  "rb"))
y_train = pickle.load(open("../models/y_train.pkl", "rb"))
y_test  = pickle.load(open("../models/y_test.pkl",  "rb"))

print("X_train shape:", X_train.shape)
print("X_test shape: ", X_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape: ", y_test.shape)
# Out:
# X_train shape: (5634, 19)
# X_test shape:  (1409, 19)
# y_train shape: (5634,)
# y_test shape:  (1409,)

# %%
# Cell 3. Train Logistic Regression(Simple Baseline Model)
lr_model = LogisticRegression(max_iter=1000, random_state=42)
lr_model.fit(X_train, y_train)

print("Logistic Regression model trained!")
# Out:
# Logistic Regression model trained!

# %%
# Cell 4. Evaluate Logistic Regression
y_pred_lr = lr_model.predict(X_test)

print("== Logistic Regression ===")
print("Accuracy:", round(accuracy_score(y_test, y_pred_lr), 4))
print("\nClassification Report:")
print(classification_report(y_test, y_pred_lr))
# Out:
# == Logistic Regression ===
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 5
#       1 # Cell 4. Evaluate Logistic Regression
#       2 y_pred_lr = lr_model.predict(X_test)
#       3
#       4 print("== Logistic Regression ===")
# ----> 5 print("Accuracy:", accuracy_score(y_test, y_pred_lr).round(4))
#       6 print("\nClassification Report:")
#       7 print(classification_report(y_test, y_pred_lr))
#
# AttributeError: 'float' object has no attribute 'round'
